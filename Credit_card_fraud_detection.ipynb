# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"creditcard.csv")

# %%
c_data = data.copy()
c_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
c_data.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
c_data_corr = c_data.corr()
c_data_corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
#  htmap = sns.heatmap(c_data_corr, cmap = 'magma', cbar = True, annot = True, annot_kws = {'size': 1})

# %%
c_data.drop(['V2', 'V5', 'V7', 'V20'], axis = 1, inplace = True)

# %%
c_data.head()
# Out:
#    Time        V1        V3        V4        V6        V8        V9       V10  \
# 0   0.0 -1.359807  2.536347  1.378155  0.462388  0.098698  0.363787  0.090794
# 1   0.0  1.191857  0.166480  0.448154 -0.082361  0.085102 -0.255425 -0.166974
# 2   1.0 -1.358354  1.773209  0.379780  1.800499  0.247676 -1.514654  0.207643
# 3   1.0 -0.966272  1.792993 -0.863291  1.247203  0.377436 -1.387024 -0.054952
# 4   2.0 -1.158233  1.548718  0.403034  0.095921 -0.270533  0.817739  0.753074
#
#         V11       V12  ...       V21       V22       V23       V24       V25  \
# 0 -0.551600 -0.617801  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  1.612727  1.065235  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.624501  0.066084  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3 -0.226487  0.178228  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.822843  0.538196  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# class values counts
c_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud = c_data[c_data['Class'] == 1]

fraud.describe()
# Out:
#                 Time          V1          V3          V4          V6  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948   -7.033281    4.542029   -1.397737
# std     47835.365138    6.783687    7.110937    2.873318    1.858124
# min       406.000000  -30.552380  -31.103685   -1.313275   -6.406267
# 25%     41241.500000   -6.036063   -8.643489    2.373050   -2.501511
# 50%     75568.500000   -2.342497   -5.075257    4.177147   -1.424616
# 75%    128483.000000   -0.419200   -2.276185    6.348729   -0.413216
# max    170348.000000    2.132386    2.250210   12.114672    6.474115
#
#                V8          V9         V10         V11         V12  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean     0.570636   -2.581123   -5.676883    3.800173   -6.259393  ...
# std      6.797831    2.500896    4.897341    2.678605    4.654458  ...
# ...

# %%
not_fraud =c_data[c_data['Class'] == 0]
not_fraud.describe()
# Out:
#                 Time             V1             V3             V4  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258       0.012171      -0.007860
# std     47484.015786       1.929814       1.459429       1.399333
# min         0.000000     -56.407510     -48.325589      -5.683171
# 25%     54230.000000      -0.917544      -0.884541      -0.850077
# 50%     84711.000000       0.020023       0.182158      -0.022405
# 75%    139333.000000       1.316218       1.028372       0.737624
# max    172792.000000       2.454930       9.382558      16.875344
#
#                   V6             V8             V9            V10  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean        0.002419      -0.000987       0.004467       0.009824
# std         1.329913       1.161283       1.089372       1.044204
# min       -26.160506     -73.216718      -6.290730     -14.741096
# ...

# %%
fraud_count = len(fraud)
fraud_count
# Out:
# 492

# %%
not_fraud_count = len(not_fraud)
not_fraud_count
# Out:
# 284315

# %%
fraud_per = fraud_count/ len(c_data)*100
print('fraud percentage :{}', fraud_per)
# Out:
# fraud percentage :{} 0.1727485630620034

# %%
notfraud_per = not_fraud_count / len(c_data)* 100
print('not fraud percentage :{}', notfraud_per)
# Out:
# not fraud percentage :{} 99.82725143693798

# %%
# countplot for fraud, notfraud percentage

ctplot_class = sns.countplot(x = 'Class', data = c_data)

# %%
# piechart for Class
data = (notfraud_per, fraud_per)
keys = ['not fraud','fraud']

pieplot_class = plt.pie(data, labels = keys)

# %%
# distplot fro 'Time'

distplot_time = sns.distplot(c_data['Time'])
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
c_data['Time'].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
# distplot for 'Amount'

distplot_amount = sns.distplot(c_data['Amount'])
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
c_data.head()
# Out:
#    Time        V1        V3        V4        V6        V8        V9       V10  \
# 0   0.0 -1.359807  2.536347  1.378155  0.462388  0.098698  0.363787  0.090794
# 1   0.0  1.191857  0.166480  0.448154 -0.082361  0.085102 -0.255425 -0.166974
# 2   1.0 -1.358354  1.773209  0.379780  1.800499  0.247676 -1.514654  0.207643
# 3   1.0 -0.966272  1.792993 -0.863291  1.247203  0.377436 -1.387024 -0.054952
# 4   2.0 -1.158233  1.548718  0.403034  0.095921 -0.270533  0.817739  0.753074
#
#         V11       V12  ...       V21       V22       V23       V24       V25  \
# 0 -0.551600 -0.617801  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  1.612727  1.065235  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.624501  0.066084  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3 -0.226487  0.178228  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.822843  0.538196  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ### splittng dataset into Features and Target

# %%
x = c_data.drop(['Class'], axis = 1)
y = c_data['Class']

# %% [markdown]
# ### Logistic regression

# %%
# splitting dataset into training and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
# logistic regression model

from sklearn.linear_model import LogisticRegression

loreg = LogisticRegression(random_state = 0)
loreg.fit(x_train, y_train)
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
# predict the testset result 

y_pred = loreg.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 168367    0
# 110270    0
# 243562    0
# 74702     0
# 98416     0
#          ..
# 27285     0
# 135082    0
# 169296    0
# 58125     0
# 53657     0
# Name: Class, Length: 85443, dtype: int64

# %%
#  Checking training score and test score

loreg_train_score = loreg.score(x_train, y_train)
print('Training score :', loreg_train_score)

loreg_test_score = loreg.score(x_test, y_test)
print("Test score :", loreg_test_score)
# Out:
# Training score : 0.9989115386930438
# Test score : 0.999133925541004

# %%
# checking model score using confusion metrix

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[85261,    41],
#        [   33,   108]], dtype=int64)

# %%
# precision score

from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)
precision
# Out:
# 0.7248322147651006

# %%
# Recall score

from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred)
recall
# Out:
# 0.7659574468085106

# %%
# f1 score

from sklearn.metrics import f1_score
f1_score = f1_score(y_test, y_pred)
f1_score
# Out:
# 0.7448275862068965

# %% [markdown]
# ### Decision tree

# %%
# splitting dataset into training and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.tree import DecisionTreeClassifier

dtcr2 = DecisionTreeClassifier(random_state = 0, max_depth = 2)
dtcr2
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
dtcr2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
# predict the testset result 

y_pred = dtcr2.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 168367    0
# 110270    0
# 243562    0
# 74702     0
# 98416     0
#          ..
# 27285     0
# 135082    0
# 169296    0
# 58125     0
# 53657     0
# Name: Class, Length: 85443, dtype: int64

# %%
dtcr2_score_train = dtcr2.score(x_train, y_train)

# %%
print("Training score :", dtcr2_score_train)
# Out:
# Training score : 0.9992425914407816

# %%
dtcr2_score_test = dtcr2.score(x_test, y_test)

# %%
print("Test score :", dtcr2_score_test)
# Out:
# Test score : 0.9994265182636377

# %%
# checking model score using cunfusion metrix 

from sklearn.metrics import confusion_matrix
cm_dt = confusion_matrix(y_test, y_pred)
cm_dt
# Out:
# array([[85283,    19],
#        [   30,   111]], dtype=int64)

# %%
# checkimg Precision score

from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)
precision
# Out:
# 0.8538461538461538

# %%
# checking recall score

from sklearn.metrics import recall_score
recall = precision_score(y_test, y_pred)
recall
# Out:
# 0.8538461538461538

# %%
# checking F1 score

from sklearn.metrics import f1_score
f1_score = f1_score(y_test, y_pred)
f1_score
# Out:
# 0.8191881918819187

# %% [markdown]
# ###  Random forest

# %%
# splitting dataset into training and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf = RandomForestClassifier(n_estimators = 100)
rfclf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# predict the testset result 

y_pred = rfclf.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 168367    0
# 110270    0
# 243562    0
# 74702     0
# 98416     0
#          ..
# 27285     0
# 135082    0
# 169296    0
# 58125     0
# 53657     0
# Name: Class, Length: 85443, dtype: int64

# %%
# checking accuracy using matrics

# from sklearn import metrics
# print(metrics.accuracy_score(y_test, y_pred))

# %%
# checking train test score

rfclf_train_score = rfclf.score(x_train, y_train)
print('Training score :', rfclf_train_score)
# Out:
# Training score : 1.0

# %%
rfclf_test_score = rfclf.score(x_test, y_test)
print("Test score :", rfclf_test_score)
# Out:
# Test score : 0.9996488887328394

# %%
# checking model score using cunfusion metrix 

from sklearn.metrics import confusion_matrix
rf_clf_cm = confusion_matrix(y_test, y_pred)
rf_clf_cm
# Out:
# array([[85297,     5],
#        [   25,   116]], dtype=int64)

# %%
# checking precision score

from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)
precision
# Out:
# 0.9586776859504132

# %%
# checking recall score

from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred)
recall
# Out:
# 0.8226950354609929

# %%
# checking F1 score

from sklearn.metrics import f1_score
f1_score = f1_score(y_test, y_pred)
f1_score
# Out:
# 0.8854961832061068

# %% [markdown]
# ###  SVM

# %%
# splitting dataset into training and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.svm import SVC

# %%
svc_md = SVC(gamma = 3)

# %%
# svc_md.fit(x_train, y_train)

# %%
# predict the testset result

y_pred = svc_md.predict(x_test)
y_pred

# %%
y_test

# %%
# checking train and test score 

svc_md_trainscore = svc_md_trainscore.score(x_train, y_train)
print("Traunung score :", svc_md_trainscore)


svc_md_testscore= svc_md_testscore.score(x_test, y_test)
print("Test score :", svc_md_testscore)

# %%
# checking model score using cunfusion metrix 

from sklearn.metrics import confusion_matrics
cm = confusion_matrics(y_test, y_pred)
cm

# %%
# checking precision score 

from sklearn.metrics import precision_score
precision = precision_matrics(y_test, y_pred)
precision

# %%
# checking recall score 

from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred)
recall

# %%
# checking F1 score 

from sklearn.metrics import f1_score
f1_score = f1_score(y_test, y_pred)
f1_score

# %% [markdown]
# ###  Gradient boosting

# %%
# it is used to refine the algorithm

# %%
# splitting dataset into training and test set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(random_state = 10)
gbr.fit(x_train, y_train)

# %%
# predict the test set result

y_pred = gbr.predict(x_test)
y_pred

# %%
y_test

# %%
print("Training Score :", gbr.score(x_train, y_train))

# %%
print("Test Score :", gbr.score(x_test, y_test))

# %%
# checking model score using confusion metrix

from sklearn.mertics import confusion_matrix
conf_gbr = confusion_matrix(y_test, y_pred)
conf_gbr

# %%
# checking precision score

from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)
precision

# %%
# checking recall score

from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred)
recall

# %%
# checking F1 score

from sklearn.metrics import f1_score
f1score = f1_score(y_test, y_pred)
f1score

# %%
#####

# %%
new_data = c_data.copy()
new_data.head()
# Out:
#    Time        V1        V3        V4        V6        V8        V9       V10  \
# 0   0.0 -1.359807  2.536347  1.378155  0.462388  0.098698  0.363787  0.090794
# 1   0.0  1.191857  0.166480  0.448154 -0.082361  0.085102 -0.255425 -0.166974
# 2   1.0 -1.358354  1.773209  0.379780  1.800499  0.247676 -1.514654  0.207643
# 3   1.0 -0.966272  1.792993 -0.863291  1.247203  0.377436 -1.387024 -0.054952
# 4   2.0 -1.158233  1.548718  0.403034  0.095921 -0.270533  0.817739  0.753074
#
#         V11       V12  ...       V21       V22       V23       V24       V25  \
# 0 -0.551600 -0.617801  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  1.612727  1.065235  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.624501  0.066084  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3 -0.226487  0.178228  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.822843  0.538196  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 27 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   V6      284807 non-null  float64
#  5   V8      284807 non-null  float64
#  6   V9      284807 non-null  float64
#  7   V10     284807 non-null  float64
#  8   V11     284807 non-null  float64
#  9   V12     284807 non-null  float64
#  10  V13     284807 non-null  float64
#  11  V14     284807 non-null  float64
#  12  V15     284807 non-null  float64
#  13  V16     284807 non-null  float64
#  14  V17     284807 non-null  float64
#  15  V18     284807 non-null  float64
#  16  V19     284807 non-null  float64
#  17  V21     284807 non-null  float64
#  18  V22     284807 non-null  float64
#  19  V23     284807 non-null  float64
# ...

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
over = SMOTE(sampling_strategy = 0.5)
f1 = new_data.iloc[:, : 26]
t1 = new_data.iloc[:, 26]
f1, t1 = over.fit_resample(f1, t1)

# %%
f1.head()
# Out:
#    Time        V1        V3        V4        V6        V8        V9       V10  \
# 0   0.0 -1.359807  2.536347  1.378155  0.462388  0.098698  0.363787  0.090794
# 1   0.0  1.191857  0.166480  0.448154 -0.082361  0.085102 -0.255425 -0.166974
# 2   1.0 -1.358354  1.773209  0.379780  1.800499  0.247676 -1.514654  0.207643
# 3   1.0 -0.966272  1.792993 -0.863291  1.247203  0.377436 -1.387024 -0.054952
# 4   2.0 -1.158233  1.548718  0.403034  0.095921 -0.270533  0.817739  0.753074
#
#         V11       V12  ...       V19       V21       V22       V23       V24  \
# 0 -0.551600 -0.617801  ...  0.403993 -0.018307  0.277838 -0.110474  0.066928
# 1  1.612727  1.065235  ... -0.145783 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.624501  0.066084  ... -2.261857  0.247998  0.771679  0.909412 -0.689281
# 3 -0.226487  0.178228  ... -1.232622 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.822843  0.538196  ...  0.803487 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
f1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426472 entries, 0 to 426471
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    426472 non-null  float64
#  1   V1      426472 non-null  float64
#  2   V3      426472 non-null  float64
#  3   V4      426472 non-null  float64
#  4   V6      426472 non-null  float64
#  5   V8      426472 non-null  float64
#  6   V9      426472 non-null  float64
#  7   V10     426472 non-null  float64
#  8   V11     426472 non-null  float64
#  9   V12     426472 non-null  float64
#  10  V13     426472 non-null  float64
#  11  V14     426472 non-null  float64
#  12  V15     426472 non-null  float64
#  13  V16     426472 non-null  float64
#  14  V17     426472 non-null  float64
#  15  V18     426472 non-null  float64
#  16  V19     426472 non-null  float64
#  17  V21     426472 non-null  float64
#  18  V22     426472 non-null  float64
#  19  V23     426472 non-null  float64
# ...

# %%
t1.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

f1_train, f1_test, t1_train, t1_test = train_test_split(f1, t1, test_size = 0.3, random_state = 5)

# %% [markdown]
# ###  Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtcr2 = DecisionTreeClassifier(random_state = 5, max_depth = 2)
dtcr2
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=5)

# %%
# predict on training data

# %%
dtcr2.fit(f1_train, t1_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=5)

# %%
t1_pred = dtcr2.predict(f1_test) 
t1_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
t1_test
# Out:
# 401454    1
# 223472    0
# 274040    0
# 130923    0
# 382420    1
#          ..
# 53181     0
# 248280    0
# 5059      0
# 230291    0
# 137465    0
# Name: Class, Length: 127942, dtype: int64

# %%
from sklearn.metrics import accuracy_score

accr = accuracy_score(t1_test, t1_pred)
accr
# Out:
# 0.9632567882321676

# %%
# predict on test data

# %%
dtcr2.fit(f1_test, t1_test)
dtcr2
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=5)

# %%
f1_pred = dtcr2.predict(f1_train)
f1_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
# accouracy score for tst data 
accr = accuracy_score(t1_test, t1_pred)
accr
# Out:
# 0.9632567882321676

# %% [markdown]
# ### Anova score for feature selection

# %%
# anova Score for feature selection 

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %%
help(SelectKBest)
# Out:
# Help on class SelectKBest in module sklearn.feature_selection._univariate_selection:
#
# class SelectKBest(_BaseFilter)
#  |  SelectKBest(score_func=<function f_classif at 0x0000021192D5A820>, *, k=10)
#  |
#  |  Select features according to the k highest scores.
#  |
#  |  Read more in the :ref:`User Guide <univariate_feature_selection>`.
#  |
#  |  Parameters
#  |  ----------
#  |  score_func : callable, default=f_classif
#  |      Function taking two arrays X and y, and returning a pair of arrays
#  |      (scores, pvalues) or a single array with scores.
#  |      Default is f_classif (see below "See Also"). The default function only
#  |      works with classification tasks.
#  |
#  |      .. versionadded:: 0.18
#  |
#  |  k : int or "all", default=10
#  |      Number of top features to select.
#  |      The "all" option bypasses selection, for use in a parameter search.
#  |
#  |  Attributes
#  |  ----------
#  |  scores_ : array-like of shape (n_features,)
# ...

# %%
bf  = SelectKBest(score_func = f_classif, k = 10 )

# %%
ft = bf.fit(f1, t1)
ft
# Out:
# SelectKBest()

# %%
print(ft.scores_)
# Out:
# [8.26299143e+03 1.38129965e+05 2.96941188e+05 5.70847582e+05
#  8.95837764e+04 1.72174953e+03 2.66843864e+05 4.19453444e+05
#  5.32042476e+05 5.56037534e+05 8.98537177e+02 8.86665901e+05
#  1.30415462e+03 3.53279931e+05 3.04163230e+05 1.72405605e+05
#  4.26728694e+04 1.11651542e+04 3.69310842e+01 6.56249575e+00
#  3.50719836e+03 8.80925118e+02 1.36371597e+03 3.82559651e+03
#  4.41255952e+03 3.64267142e+02]

# %%
type(ft.scores_)
# Out:
# numpy.ndarray

# %%
print(ft.pvalues_)
# Out:
# [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 3.27744255e-197 0.00000000e+000
#  3.82959607e-285 0.00000000e+000 0.00000000e+000 0.00000000e+000
#  0.00000000e+000 0.00000000e+000 1.22482359e-009 1.04153601e-002
#  0.00000000e+000 2.16901756e-193 4.78902457e-298 0.00000000e+000
#  0.00000000e+000 3.58416608e-081]

# %%
htmp = sns.histplot(data = ft.scores_)

# %%
df1 = pd.DataFrame(data = ft.scores_, columns = ["anova"], index =list(f1.columns))
df1 = df1.sort_values(by = 'anova', ascending = False)
df1
# Out:
#                 anova
# V14     886665.901442
# V4      570847.581669
# V12     556037.534464
# V11     532042.475854
# V10     419453.443551
# V16     353279.930915
# V17     304163.230149
# V3      296941.187739
# V9      266843.864117
# V18     172405.605132
# V1      138129.964791
# V6       89583.776372
# V19      42672.869420
# V21      11165.154186
# Time      8262.991427
# V28       4412.559515
# V27       3825.596506
# V24       3507.198363
# V8        1721.749534
# V26       1363.715967
# V15       1304.154624
# V13        898.537177
# V25        880.925118
# Amount     364.267142
# V22         36.931084
# V23          6.562496

# %% [raw]
# Now, we can drop the columns with low anova scores
